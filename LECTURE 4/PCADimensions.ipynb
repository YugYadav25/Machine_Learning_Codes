# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.decomposition import PCA

# %%
X,y_true=make_blobs(n_samples=500, n_features=3,centers=3,cluster_std=1.5,random_state=42)

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
pca=PCA(n_components=2)
X_pca=pca.fit_transform(X_scaled)

# %%
X_pca
# Out:
# array([[ 1.48738432, -0.73218323],
#        [ 1.02615958,  0.61939421],
#        [-2.07715552, -0.3594655 ],
#        [ 1.2443682 , -0.77632387],
#        [ 1.37313462,  0.40870887],
#        [ 1.3604949 , -1.03261907],
#        [-1.95006944,  0.01615306],
#        [-1.80972136, -0.42591362],
#        [ 1.36210274, -0.64033951],
#        [ 1.38984388,  0.4857247 ],
#        [ 0.9947474 , -0.5393958 ],
#        [-1.7263535 , -0.18784656],
#        [ 0.72448637,  0.70332467],
#        [-1.62907925,  0.00736454],
#        [ 0.7309046 , -0.46082088],
#        [ 0.91566654,  0.45903386],
#        [-2.20025635,  0.14374038],
#        [ 1.36686004, -0.39937548],
#        [ 1.38618781,  0.3344959 ],
#        [ 0.88844236,  0.93372118],
#        [ 0.59878659,  0.61117029],
#        [ 1.24923649, -0.72617808],
#        [-2.15833078,  0.3637809 ],
#        [-2.24146611,  0.1123177 ],
#        [-2.01687005, -0.2451555 ],
#        [ 0.98746086,  0.58264534],
#        [ 1.39595494, -1.41863032],
# ...

# %%
 X
# Out:
# array([[-10.19072888,   4.98081262,   5.02490589],
#        [ -3.37126143,   8.3820388 ,   5.14961028],
#        [  0.88816106,  -3.22885507,  -9.53547438],
#        ...,
#        [  2.72277611,  -6.08073453,  -8.511781  ],
#        [ -2.96268399,   9.00744188,   3.61636493],
#        [ -3.77540299,   8.49948427,   5.32639352]])

# %%
df_pca=pd.DataFrame(X_pca,columns=['PC1','PC2'])
df_pca['label']=y_true

# %%
sns.scatterplot(data=df_pca,x='PC1',y='PC2',hue='label',palette='Set2')
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>

# %% [markdown]
# # 5-D Dimension Reduced to 2-D Dimension in above analysis
