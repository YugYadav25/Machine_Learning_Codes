# %%
 
 import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os import name
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/NLP/train.txt',sep=';',header=None,names=['text','emotion'])

# %%
df.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
df.isnull().sum()
# Out:
# text       0
# emotion    0
# dtype: int64

# %%
unique = df['emotion'].unique()
dictionary={}
i=0
for u in unique:
  dictionary[u]=i
  i+=1

dictionary
# Out:
# {'sadness': 0, 'anger': 1, 'love': 2, 'surprise': 3, 'fear': 4, 'joy': 5}

# %%
df['emotion']=df['emotion'].map(dictionary)

# %%
df.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated        0
# 1  i can go from feeling so hopeless to so damned...        0
# 2   im grabbing a minute to post i feel greedy wrong        1
# 3  i am ever feeling nostalgic about the fireplac...        2
# 4                               i am feeling grouchy        1

# %%
# sabse small function likhna ho to that is lambda function

# we are currently doint text cleaning

# %%
import string

def remove_punc(txt):
  return txt.translate(str.maketrans('','',string.punctuation))

# %%
df['text']=df['text'].apply(remove_punc)

# %%
import re

def remove_numbers(text):
  return re.sub(r'\d+', '', text)

# %%
# code to remove emojis

import re

def remove_emojis(text):
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"
        "\U0001F300-\U0001F5FF"
        "\U0001F680-\U0001F6FF"
        "\U0001F1E0-\U0001F1FF"
        "\U00002702-\U000027B0"
        "\U000024C2-\U0001F251"
        "]+"
    )
    return emoji_pattern.sub(r'', text)

# %%
df['text'] = df['text'].apply(remove_emojis)

# %%
df.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated        0
# 1  i can go from feeling so hopeless to so damned...        0
# 2   im grabbing a minute to post i feel greedy wrong        1
# 3  i am ever feeling nostalgic about the fireplac...        2
# 4                               i am feeling grouchy        1

# %%
df['text'] = df['text'].apply(remove_numbers)

# %%
df.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated        0
# 1  i can go from feeling so hopeless to so damned...        0
# 2   im grabbing a minute to post i feel greedy wrong        1
# 3  i am ever feeling nostalgic about the fireplac...        2
# 4                               i am feeling grouchy        1

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# In machine learning, a corpus simply means a large, structured collection of data, usually text, that is used to train, test, or evaluate models.

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
pip uninstall nltk -y
# Out:
# Found existing installation: nltk 3.9.4
# Uninstalling nltk-3.9.4:
#   Successfully uninstalled nltk-3.9.4

# %%
pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# ...

# %%
import nltk
print(f"NLTK version: {nltk.__version__}")
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# NLTK version: 3.9.4
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words=set(stopwords.words('english'))

# %%
import pandas as pd
try:
    df = pd.read_csv('/content/drive/MyDrive/Machine Learning/NLP/train.txt', sep=';', header=None, names=['text','emotion'])
    print('Dataframe loaded successfully.')
    display(df.head())
except Exception as e:
    print(f'Error loading file: {e}')
# Out:
# Dataframe loaded successfully.
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
df.loc[1]['text']
# Out:
# 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake'

# %%
def remove_stopward(txt):
    words = split(txt)

    cleaned = [i for i in words if i.lower() not in stop_words]
    return ' '.join(cleaned)

# %%
df['text']=df['text'].apply(remove_stopward)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2859/2282623007.py in <cell line: 0>()
# ----> 1 df['text']=df['text'].apply(remove_stopward)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# ...

# %%
# this will make sure that the text is now clean
